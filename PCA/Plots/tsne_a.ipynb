# %%
library(ggplot2)
data=read.csv("/home/naina/Desktop/datamining/tsne_a_file.csv")
df=as.data.frame(data)
df <- subset(df, select = -c(X) )
#df
df$X2 <- gsub("b" ,"", df$X2)
df
# Out:
#     X0       X1        X2
# 1   6.107786 -1.919456 'Asthma'
# 2   6.687282 -1.706872 'Arrhythmia'
# 3   5.207324 -2.298827 'Hypertension'
# 4   7.431396 -2.368554 'Arrhythmia'
# 5   4.754493 -1.997321 'Hypertension'
# 6   6.519345 -2.292630 'Arrhythmia'
# 7   5.329356 -2.389989 'Hypertension'
# 8   7.506790 -2.126823 'Arrhythmia'
# 9   6.007593 -2.331009 'Asthma'
# 10  6.289060 -1.616406 'Arrhythmia'
# 11  6.320023 -1.743469 'Arrhythmia'
# 12  6.489722 -2.343467 'Asthma'
# 13  5.958387 -1.791375 'Asthma'
# 14  5.318660 -2.304123 'Hypertension'
# 15  6.937293 -2.138717 'Arrhythmia'
# 16  5.144173 -2.308398 'Hypertension'
# 17  6.097734 -1.724934 'Asthma'
# 18  6.205923 -1.971071 'Asthma'
# 19  6.217522 -1.847567 'Asthma'
# 20  5.272242 -2.311134 'Hypertension'
# 21  6.790813 -1.778716 'Arrhythmia'
# 22  5.066947 -2.189325 'Hypertension'
# 23  5.329551 -1.950349 'Hypertension'
# 24  6.174276 -2.393282 'Asthma'
# 25  6.780786 -2.363739 'Arrhythmia'
# 26  6.064809 -2.015632 'Asthma'
# 27  5.907894 -1.469051 'Asthma'
# 28  7.806138 -2.319737 'Arrhythmia'
# 29  4.665191 -2.055101 'Hypertension'
# 30  4.990429 -2.300521 'Hypertension'
# ⋮   ⋮        ⋮         ⋮
# 121 5.868403 -2.920941 'Hypertension'
# 122 5.208769 -2.375033 'Hypertension'
# 123 5.926199 -1.928009 'Asthma'
# 124 5.834848 -1.577620 'Asthma'
# 125 5.905027 -2.096182 'Asthma'
# 126 4.993642 -2.398607 'Hypertension'
# 127 5.392894 -2.665015 'Hypertension'
# 128 6.342184 -2.191857 'Asthma'
# 129 5.867318 -1.827275 'Asthma'
# 130 6.498150 -1.681259 'Arrhythmia'
# 131 6.654707 -1.558909 'Arrhythmia'
# 132 6.297793 -2.120033 'Arrhythmia'
# 133 5.872133 -2.525059 'Hypertension'
# 134 5.121783 -1.868931 'Asthma'
# 135 5.177224 -2.403012 'Hypertension'
# 136 6.706035 -2.496814 'Asthma'
# 137 5.741297 -2.232709 'Asthma'
# 138 6.965947 -1.958325 'Arrhythmia'
# 139 5.571693 -2.109816 'Hypertension'
# 140 6.404472 -1.951037 'Asthma'
# 141 6.980780 -2.419911 'Arrhythmia'
# 142 5.355506 -2.341781 'Hypertension'
# 143 6.456411 -2.349567 'Asthma'
# 144 6.044093 -1.643451 'Arrhythmia'
# 145 7.558603 -2.140041 'Arrhythmia'
# 146 5.948453 -2.330989 'Asthma'
# 147 5.545833 -1.965517 'Asthma'
# 148 6.538041 -1.872309 'Arrhythmia'
# 149 5.135077 -2.299718 'Hypertension'
# 150 4.925833 -2.233886 'Hypertension'

# %%
ggplot(df, aes(x=df$X0, y=df$X1, color=df$X2)) + scale_x_continuous("Principal_Component1") +
  scale_y_continuous("Principal_Component2") +
  ggtitle("TSNE Plot")+labs(colour="Disease")+
    geom_point(size=2, alpha=0.6)
# Out:
# plot without title
