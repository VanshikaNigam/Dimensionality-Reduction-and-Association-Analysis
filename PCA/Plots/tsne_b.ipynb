# %%
library(ggplot2)
data=read.csv("/home/naina/Desktop/datamining/tsne_b_file.csv")
df=as.data.frame(data)
df <- subset(df, select = -c(X) )
#df
df$X2 <- gsub("b" ,"", df$X2)
df
# Out:
#     X0          X1           X2
# 1   -0.89756201 -0.15558451  'Septic'
# 2   -1.00404504  0.59998262  'HVD'
# 3   -1.29689741  0.19601867  'HVD'
# 4   -0.29927092 -0.69485957  'Septic'
# 5    0.28935196 -0.71548900  'TB'
# 6   -0.07901877 -0.97488720  'CD'
# 7   -0.37759771 -0.23018482  'TB'
# 8   -0.38353102 -0.57916255  'CD'
# 9    0.52656317  1.17332610  'Septic'
# 10  -0.63431020 -0.17746617  'Septic'
# 11  -0.98601249 -0.80394870  'TB'
# 12   0.45205467 -0.08388680  'Septic'
# 13  -0.85108501 -0.73350256  'Septic'
# 14  -0.87666887  0.18605779  'HVD'
# 15  -0.53692841 -0.21464002  'CD'
# 16  -1.05895277 -0.01872129  'HVD'
# 17  -0.48732204 -0.86550356  'CD'
# 18  -0.25841266 -0.19692914  'Septic'
# 19  -0.43261902 -0.68011866  'CD'
# 20  -0.61654635 -0.45320716  'TB'
# 21  -1.37371982  0.47807201  'HVD'
# 22  -0.40516335 -0.74906594  'CD'
# 23  -0.28286722 -0.11159759  'HVD'
# 24  -0.68073710  0.07383840  'HVD'
# 25  -0.74235394 -0.82151064  'CA'
# 26  -0.48589082 -0.59826000  'Septic'
# 27  -0.86992512 -0.29450285  'Septic'
# 28  -0.19567647 -0.09571628  'CD'
# 29  -0.85354127  0.48502939  'CA'
# 30  -0.66999600 -0.79121015  'CA'
# ⋮   ⋮           ⋮            ⋮
# 357 -0.03044246 -0.906788937 'CD'
# 358  0.50002248 -0.967355698 'CD'
# 359 -0.47638178 -0.237930670 'Septic'
# 360 -0.44727378 -0.317617224 'Septic'
# 361 -0.44524485 -0.048211877 'Septic'
# 362 -0.09992292 -0.606540653 'CA'
# 363 -0.88797225 -0.768397810 'Septic'
# 364 -0.22101874  0.001806655 'HVD'
# 365 -0.41773761 -0.858878675 'CA'
# 366 -0.23622346 -1.232819782 'CD'
# 367  0.43420038 -0.727027690 'CD'
# 368  0.13218225 -0.612337507 'Septic'
# 369 -0.33592072 -0.657008268 'Septic'
# 370 -0.67064643 -0.490297124 'CA'
# 371 -0.65339666 -0.646315239 'Septic'
# 372 -0.24291084 -1.213666579 'CD'
# 373 -0.10464230 -1.026522907 'CA'
# 374 -0.50010672 -1.091605592 'CA'
# 375 -0.11905073 -1.394850964 'CD'
# 376 -0.21999099 -0.029915339 'Septic'
# 377  0.92542237 -1.136278813 'TB'
# 378 -0.21724169 -0.696113444 'CD'
# 379 -0.42899641 -0.277992274 'Septic'
# 380 -0.14923287 -0.657602758 'Septic'
# 381 -1.18034746 -0.672416010 'TB'
# 382 -0.40175004 -0.762714635 'CD'
# 383 -0.59077136 -0.306401837 'Septic'
# 384 -0.21827105 -0.379991619 'Septic'
# 385 -0.06365960 -0.774947329 'CD'
# 386 -0.66345114 -0.668631363 'HVD'

# %%
ggplot(df, aes(x=df$X0, y=df$X1, color=df$X2)) + scale_x_continuous("Principal_Component1") +
  scale_y_continuous("Principal_Component2") +
  ggtitle("TSNE Plot")+labs(colour="Disease")+
    geom_point(size=2, alpha=0.6)
# Out:
# plot without title
